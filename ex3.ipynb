# %% [markdown]
# # Intel Image Classification

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %%
batch_size = 128
lr = 1e-3
epochs = 50

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("puneet6060/intel-image-classification")

print("Path to dataset files:", path)

# %%
train_data_dir = os.path.join(path, "seg_train", "seg_train")
test_data_dir = os.path.join(path, "seg_test", "seg_test")
print(train_data_dir)
print(test_data_dir)

# %%
train_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.RandomCrop((112, 112), padding = 4),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(0.5),
    # transforms.RandomVerticalFlip(0.5),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor()
])

train_dataset = datasets.ImageFolder(root = train_data_dir, transform = train_transform)
test_dataset = datasets.ImageFolder(root = test_data_dir, transform = test_transform)

train_loader = DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)
test_loader = DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)

classes = train_dataset.classes

print(f"Train = {len(train_dataset)}, Test = {len(test_dataset)}")
print(f"Intel Image Classification classes: {classes}")

# %%
x, t = next(iter(train_loader))
x = x[0].numpy().transpose(1, 2, 0)
t = t[0].numpy()

print(f"Class = {classes[t]}")
plt.imshow(x)
plt.show()

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.name = "CNN"
        
        self.conv1 = nn.Conv2d( 3, 32, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size = 3, padding = 1)
        self.pool1 = nn.MaxPool2d(kernel_size = 2)
        self.pool2 = nn.MaxPool2d(kernel_size = 2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 28 * 28, 128)
        self.fclsv = nn.Linear(128, 2)
        self.fcout = nn.Linear(2, 6)

    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        v = self.fclsv(x)
        y = self.fcout(v)

        return y, v

# %%
class VGGBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1)
        self.pool1 = nn.MaxPool2d(kernel_size = 2)
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        y = self.pool1(x)

        return y

class VGGNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.name = "VGGNet"

        self.conv_blocks = nn.ModuleList([
            VGGBlock(in_channels = 3, out_channels = 64),
            VGGBlock(in_channels = 64, out_channels = 128),
            VGGBlock(in_channels = 128, out_channels = 256),
            VGGBlock(in_channels = 256, out_channels = 512)
        ])

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(512 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fclsv = nn.Linear(128, 2)
        self.fcout = nn.Linear(2, 6)

        self.dropout1 = nn.Dropout(0.5)
        self.dropout2 = nn.Dropout(0.5)
    
    def forward(self, x):
        for layer in self.conv_blocks:
            x = layer(x)

        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        v = self.fclsv(x)
        y = self.fcout(v)

        return y, v

# %%
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels, set_pool = None):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = 1, bias = False)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1, bias = False)
        self.conv3 = nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1, bias = False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.bn3 = nn.BatchNorm2d(out_channels)

        if set_pool == "aap":
            self.pool1 = nn.AdaptiveAvgPool2d(output_size = (1, 1))
        
        else:
            self.pool1 = nn.MaxPool2d(kernel_size = 2)
    
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        res = x
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))
        x = x + res
        x = F.relu(x)
        y = self.pool1(x)

        return y

class ResNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.name = "ResNet"

        self.conv_blocks = nn.ModuleList([
            ResNetBlock(in_channels = 3, out_channels = 64),
            ResNetBlock(in_channels = 64, out_channels = 128),
            ResNetBlock(in_channels = 128, out_channels = 256),
            ResNetBlock(in_channels = 256, out_channels = 512, set_pool = "aap")
        ])

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(512, 128)
        self.fclsv = nn.Linear(128, 2)
        self.fcout = nn.Linear(2, 6)
    
    def forward(self, x):
        for layer in self.conv_blocks:
            x = layer(x)

        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        v = self.fclsv(x)
        y = self.fcout(v)

        return y, v

# %%
model = CNN()
# model = VGGNet()
# model = ResNet()
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = lr)

# %%
history = {"loss" : [], "accuracy" : [], "test_loss" : [], "test_accuracy" : []}

for epoch in range(epochs):
    model.train()
    train_loss = 0
    train_accuracy = 0

    for x, t in tqdm(train_loader):
        x, t = x.to(device), t.to(device)

        y, v = model(x)
        loss = criterion(y, t)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)
        train_accuracy += (y.argmax(1) == t).sum().item()

    train_loss /= len(train_dataset)
    train_accuracy /= len(train_dataset)

    history["loss"].append(train_loss)
    history["accuracy"].append(train_accuracy)

    model.eval()
    test_loss = 0
    test_accuracy = 0

    with torch.no_grad():
        for x, t in tqdm(test_loader):
            x, t = x.to(device), t.to(device)
            y, v = model(x)
            loss = criterion(y, t)
            test_loss += loss.item() * x.size(0)
            test_accuracy += (y.argmax(1) == t).sum().item()

    test_loss /= len(test_dataset)
    test_accuracy /= len(test_dataset)

    history["test_loss"].append(test_loss)
    history["test_accuracy"].append(test_accuracy)

    print(f"Epoch = {epoch + 1}, ", end = "")
    print(f"Loss = {train_loss:.5f}, Accuracy = {train_accuracy:.5f}, ", end = "")
    print(f"Test Loss = {test_loss:.5f}, Test Accuracy = {test_accuracy:.5f}")

torch.save({
    "model" : model.state_dict(),
    "optimizer" : optimizer.state_dict(),
    "history" : history
}, f"{model.name}.pth")

# %%
plt.plot(range(1, epochs + 1), history["loss"], label = "Train")
plt.plot(range(1, epochs + 1), history["test_loss"], label = "Test")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle = "--")
plt.legend()
plt.show()

# %%
plt.plot(range(1, epochs + 1), history["accuracy"], label = "Train")
plt.plot(range(1, epochs + 1), history["test_accuracy"], label = "Test")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True, linestyle = "--")
plt.legend()
plt.show()

# %%
model.eval()

with torch.no_grad():
    test_accuracy = 0

    class_accuracy = [0.0 for i in range(len(classes))]
    class_datas = [0.0 for i in range(len(classes))]

    for x, t in tqdm(test_loader):
        x, t = x.to(device), t.to(device)
        y, v = model(x)
        tmp = y.argmax(1) == t
        test_accuracy += tmp.sum().item()

        c = tmp.squeeze()

        for i in range(len(t)):
            label = t[i].item()
            class_accuracy[label] += c[i].item()
            class_datas[label] += 1

    test_accuracy /= len(test_dataset)
    print(f"Test Accuracy = {test_accuracy:.5f}")

    for i in range(len(classes)):
        class_accuracy[i] /= class_datas[i]
        print(f"Accuracy of {classes[i]} = {class_accuracy[i]:.5f}")

# %%
plt.bar(classes, class_accuracy)
plt.xlabel("Class")
plt.ylabel("Accuracy")
plt.xticks(rotation = 45)
plt.ylim(0.0, 1.0)
plt.grid(axis = "y", linestyle = "--")
plt.show()

# %%
vs = []
ts = []

count = {i : 0 for i in range(len(classes))}
datas = 100

shuffled_test_dataset = DataLoader(test_dataset, batch_size = 1, shuffle = True)

with torch.no_grad():
    for x, t in shuffled_test_dataset:
        label = t.item()

        if count[label] < datas:
            x = x.to(device)
            y, v = model(x)
            vs.append(v.cpu().numpy().squeeze())
            ts.append(label)
            count[label] += 1

        if all(c == datas for c in count.values()):
            break

vs = np.array(vs)
ts = np.array(ts)

print(f"Total Datas = {len(vs)}")

# %%
for i, label in enumerate(classes):
    class_idx = np.where(ts == i)
    class_v = vs[class_idx]

    plt.scatter(class_v[:, 0], class_v[:, 1], label = label)

plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.grid(True, linestyle = "--")
plt.legend()
plt.show()

# %% [markdown]
# # Compare Models

# %%
colors = ("purple", "blue", "green", "red")

models = {
    "SimpleCNN" : CNN(),
    "CNN" : CNN(),
    "VGGNet" : VGGNet(),
    "ResNet" : ResNet()
}

histories = dict()

for name in models.keys():
    checkpoint = torch.load(f"{name}.pth")
    models[name].load_state_dict(checkpoint["model"])
    models[name] = models[name].to(device)
    histories[name] = checkpoint["history"]

# %%
for name, color in zip(models.keys(), colors):
    plt.plot(histories[name]["loss"], label = name, linestyle = "--", color = color)
    plt.plot(histories[name]["test_loss"], label = f"{name}_test", color = color)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle = "--")
plt.legend()
plt.show()

# %%
for name, color in zip(models.keys(), colors):
    plt.plot(histories[name]["accuracy"], label = name, linestyle = "--", color = color)
    plt.plot(histories[name]["test_accuracy"], label = f"{name}_test", color = color)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle = "--")
plt.legend()
plt.show()

# %%
class_accuracy = dict()
class_datas = dict()

for name in models.keys():
    print(name)

    models[name].eval()

    with torch.no_grad():
        test_accuracy = 0

        class_accuracy[name] = [0.0 for i in range(len(classes))]
        class_datas[name] = [0.0 for i in range(len(classes))]

        for x, t in tqdm(test_loader):
            x, t = x.to(device), t.to(device)
            y, v = models[name](x)
            tmp = y.argmax(1) == t
            test_accuracy += tmp.sum().item()

            c = tmp.squeeze()

            for i in range(len(t)):
                label = t[i].item()
                class_accuracy[name][label] += c[i].item()
                class_datas[name][label] += 1

        test_accuracy /= len(test_dataset)
        print(f"Test Accuracy = {test_accuracy:.5f}")

        for i in range(len(classes)):
            class_accuracy[name][i] /= class_datas[name][i]
            # print(f"Accuracy of {classes[i]} = {class_accuracy[name][i]:.5f}")

# %%
xs = {
    "SimpleCNN" : [x - 0.3 for x in range(len(classes))],
    "CNN" : [x - 0.1 for x in range(len(classes))],
    "Middle" : [x for x in range(len(classes))],
    "VGGNet" : [x + 0.1 for x in range(len(classes))],
    "ResNet" : [x + 0.3 for x in range(len(classes))]
}

for name, color in zip(models.keys(), colors):
    plt.bar(xs[name], class_accuracy[name], width = 0.2, label = name, color = color)

plt.xlabel("Class")
plt.ylabel("Accuracy")
plt.xticks(xs["Middle"], classes, rotation = 45)
plt.ylim(0.0, 1.0)
plt.grid(axis = "y", linestyle = "--")
plt.legend(ncol = len(models))
plt.show()

# %%
vs = dict()
ts = dict()

for name in models.keys():
    vs[name] = []
    ts[name] = []

    count = {i : 0 for i in range(len(classes))}
    datas = 100

    shuffled_test_dataset = DataLoader(test_dataset, batch_size = 1, shuffle = True)

    with torch.no_grad():
        for x, t in shuffled_test_dataset:
            label = t.item()

            if count[label] < datas:
                x = x.to(device)
                y, v = models[name](x)
                vs[name].append(v.cpu().numpy().squeeze())
                ts[name].append(label)
                count[label] += 1

            if all(c == datas for c in count.values()):
                break

    vs[name] = np.array(vs[name])
    ts[name] = np.array(ts[name])

    print(f"{name}: Total Datas = {len(vs[name])}")

# %%
fig, axes = plt.subplots(nrows = 1, ncols = len(models), figsize = (5 * len(models), 5))

for name, ax in zip(models.keys(), axes):
    for i, label in enumerate(classes):
        class_idx = np.where(ts[name] == i)
        class_v = vs[name][class_idx]

        ax.scatter(class_v[:, 0], class_v[:, 1], label = label)

    ax.set_title(name)
    ax.set_xlabel("Dim 1")
    ax.set_ylabel("Dim 2")
    ax.grid(True, linestyle = "--")
    ax.legend()

plt.tight_layout()
plt.show()
